# %% [markdown]
# ## Ejemplo 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Usar todo lo que aprendimos para automatizar peticiones al API
#     - Guardar nuestros resultados en un archivo tipo .csv
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Veamos cómo usar todo lo que aprendimos para automatizar el proceso de realizar múltiples peticiones a la API, reunirlas en un `DataFrame` y guardarlo en un .csv:

# %%
import pandas as pd
import requests

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
parametros = {
    'api_key': 'ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih'
}

# %% [markdown]
# Obtener 10 páginas de datos del API.

# %%
diccionarios = []
for i in range(10):
    resultados = requests.get(url, params=parametros)
    if resultados.status_code == 200:
        datos = resultados.json()
        objetos = datos["near_earth_objects"]
        diccionarios.append(objetos)
        url = datos["links"]["next"]
        parametros = {}
        print(datos["links"]["self"])
    else:
        print("Error al obtener la pagina")
# Out:
# http://www.neowsapp.com/rest/v1/neo/browse?page=0&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=1&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=2&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=3&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=4&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=5&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=6&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=7&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=8&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih
# http://www.neowsapp.com/rest/v1/neo/browse?page=9&size=20&api_key=ZfveyasLXxy7dXlzcZWnwlAHaQWVbc6xwK4Z4Qih

# %% [markdown]
# Valiando la cantidad de diccionarios obtenidos:

# %%
len(diccionarios)
# Out:
# 10

# %% [markdown]
# Validando el tipo de dato del elemento 0 de la lista:

# %%
type(diccionarios[0])
# Out:
# list

# %% [markdown]
# Normalizar y crea los dataframes usando `map` o listas de compresión:

# %%
dfs = [pd.json_normalize(d) for d in diccionarios]

# %% [markdown]
# Valida el tipo de dato del elemento 0:

# %%
type(dfs[0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Explora el inicio del dataframe del elemento 0:

# %%
dfs[0].head()
# Out:
#         id neo_reference_id                    name name_limited designation  \
# 0  2000433          2000433      433 Eros (A898 PA)         Eros         433
# 1  2000719          2000719    719 Albert (A911 TB)       Albert         719
# 2  2000887          2000887    887 Alinda (A918 AA)       Alinda         887
# 3  2001036          2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4  2001221          2001221    1221 Amor (1932 EA1)         Amor        1221
#
#                                     nasa_jpl_url  absolute_magnitude_h  \
# 0  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                 10.42
# 1  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                 15.51
# 2  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                 13.84
# 3  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                  9.25
# 4  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                 17.39
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#                                  close_approach_data  is_sentry_object  ...  \
# 0  [{'close_approach_date': '1900-12-27', 'close_...             False  ...
# 1  [{'close_approach_date': '1909-08-21', 'close_...             False  ...
# 2  [{'close_approach_date': '1910-01-04', 'close_...             False  ...
# 3  [{'close_approach_date': '1910-02-25', 'close_...             False  ...
# 4  [{'close_approach_date': '1900-03-08', 'close_...             False  ...
#
#   orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                1.133004746239758                 178.8689344298016
# 1                1.195376966739327                 156.2074111005377
# 2                1.062542630695554                 350.5075827027987
# 3                1.244392487592923                 132.3785381720509
# 4                1.083392203652344                 26.67758290479227
#
#    orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0               1.783329728038786          2459159.335547045187
# 1               4.080683758289534          2459956.001930185700
# 2                3.88479471264434          2459258.738807182354
# 3               4.085994582878027          2458979.250423075115
# 4                 2.7549388383389          2458896.584345836670
#
#    orbital_data.mean_anomaly  orbital_data.mean_motion  orbital_data.equinox  \
# 0          23.04174776493414         .5597486693246532                 J2000
# 1          231.2977977256108         .2300299522321089                 J2000
# 2           34.8994574215934         .2533330084314079                 J2000
# 3          50.11796125710877          .226522291946004                 J2000
# 4          112.6648636168215         .3707109590224443                 J2000
#
#    orbital_data.orbit_class.orbit_class_type  \
# 0                                        AMO
# 1                                        AMO
# 2                                        AMO
# 3                                        AMO
# 4                                        AMO
#
#     orbital_data.orbit_class.orbit_class_description  \
# 0  Near-Earth asteroid orbits similar to that of ...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits similar to that of ...
# 3  Near-Earth asteroid orbits similar to that of ...
# 4  Near-Earth asteroid orbits similar to that of ...
#
#   orbital_data.orbit_class.orbit_class_range
# 0         1.017 AU < q (perihelion) < 1.3 AU
# 1         1.017 AU < q (perihelion) < 1.3 AU
# 2         1.017 AU < q (perihelion) < 1.3 AU
# 3         1.017 AU < q (perihelion) < 1.3 AU
# 4         1.017 AU < q (perihelion) < 1.3 AU
#
# [5 rows x 44 columns]

# %% [markdown]
# Concatena los dataframes en un sólo dataframe y reinicia índices (por alguna buena razón hemos creado una lista de dataframes ¿cierto?):

# %%
df = pd.concat(dfs)

df
# Out:
#          id neo_reference_id                    name name_limited designation  \
# 0   2000433          2000433      433 Eros (A898 PA)         Eros         433
# 1   2000719          2000719    719 Albert (A911 TB)       Albert         719
# 2   2000887          2000887    887 Alinda (A918 AA)       Alinda         887
# 3   2001036          2001036  1036 Ganymed (A924 UB)      Ganymed        1036
# 4   2001221          2001221    1221 Amor (1932 EA1)         Amor        1221
# ..      ...              ...                     ...          ...         ...
# 15  2017511          2017511         17511 (1992 QN)          NaN       17511
# 16  2018106          2018106  18106 Blume (2000 NX3)        Blume       18106
# 17  2018109          2018109       18109 (2000 NG11)          NaN       18109
# 18  2018172          2018172        18172 (2000 QL7)          NaN       18172
# 19  2018736          2018736         18736 (1998 NU)          NaN       18736
#
#                                      nasa_jpl_url  absolute_magnitude_h  \
# 0   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433                 10.42
# 1   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719                 15.51
# 2   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887                 13.84
# 3   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036                  9.25
# 4   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221                 17.39
# ..                                            ...                   ...
# 15  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2017511                 17.30
# 16  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018106                 17.70
# 17  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018109                 17.08
# 18  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018172                 15.61
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018736                 15.94
#
#     is_potentially_hazardous_asteroid  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ..                                ...
# 15                              False
# 16                              False
# 17                              False
# 18                              False
# 19                              False
#
#                                   close_approach_data  is_sentry_object  ...  \
# 0   [{'close_approach_date': '1900-12-27', 'close_...             False  ...
# 1   [{'close_approach_date': '1909-08-21', 'close_...             False  ...
# 2   [{'close_approach_date': '1910-01-04', 'close_...             False  ...
# 3   [{'close_approach_date': '1910-02-25', 'close_...             False  ...
# 4   [{'close_approach_date': '1900-03-08', 'close_...             False  ...
# ..                                                ...               ...  ...
# 15  [{'close_approach_date': '1900-12-11', 'close_...             False  ...
# 16  [{'close_approach_date': '1904-08-28', 'close_...             False  ...
# 17  [{'close_approach_date': '1902-10-30', 'close_...             False  ...
# 18  [{'close_approach_date': '1913-11-01', 'close_...             False  ...
# 19  [{'close_approach_date': '1918-04-01', 'close_...             False  ...
#
#    orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                 1.133004746239758                 178.8689344298016
# 1                 1.195376966739327                 156.2074111005377
# 2                 1.062542630695554                 350.5075827027987
# 3                 1.244392487592923                 132.3785381720509
# 4                 1.083392203652344                 26.67758290479227
# ..                              ...                               ...
# 15                .7628812639160113                 202.3575672368542
# 16                1.193699063724138                 234.9170096326625
# 17                1.189336449752271                 319.2321665645002
# 18                1.185283315346584                 100.7630208867756
# 19                1.198402888557957                 222.8832249073757
#
#     orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0                1.783329728038786          2459159.335547045187
# 1                4.080683758289534          2459956.001930185700
# 2                 3.88479471264434          2459258.738807182354
# 3                4.085994582878027          2458979.250423075115
# 4                  2.7549388383389          2458896.584345836670
# ..                             ...                           ...
# 15               1.617050971155794          2459164.094158202908
# 16               3.696433765221722          2458767.595284876645
# 17               2.572445554033802          2459350.582381827407
# 18               3.663375081197811          2458829.950952856585
# 19               3.503564851581627          2459871.090996946585
#
#     orbital_data.mean_anomaly  orbital_data.mean_motion  orbital_data.equinox  \
# 0           23.04174776493414         .5597486693246532                 J2000
# 1           231.2977977256108         .2300299522321089                 J2000
# 2            34.8994574215934         .2533330084314079                 J2000
# 3           50.11796125710877          .226522291946004                 J2000
# 4           112.6648636168215         .3707109590224443                 J2000
# ..                        ...                       ...                   ...
# 15          176.4611969338573         .7592803845607337                 J2000
# 16          111.5990248305691         .2577911973048602                 J2000
# 17          17.54437829266421         .3820838055388477                 J2000
# 18          96.75254254087584         .2611059002492302                 J2000
# 19          230.2375325755811         .2734195723460461                 J2000
#
#     orbital_data.orbit_class.orbit_class_type  \
# 0                                         AMO
# 1                                         AMO
# 2                                         AMO
# 3                                         AMO
# 4                                         AMO
# ..                                        ...
# 15                                        APO
# 16                                        AMO
# 17                                        AMO
# 18                                        AMO
# 19                                        AMO
#
#      orbital_data.orbit_class.orbit_class_description  \
# 0   Near-Earth asteroid orbits similar to that of ...
# 1   Near-Earth asteroid orbits similar to that of ...
# 2   Near-Earth asteroid orbits similar to that of ...
# 3   Near-Earth asteroid orbits similar to that of ...
# 4   Near-Earth asteroid orbits similar to that of ...
# ..                                                ...
# 15  Near-Earth asteroid orbits which cross the Ear...
# 16  Near-Earth asteroid orbits similar to that of ...
# 17  Near-Earth asteroid orbits similar to that of ...
# 18  Near-Earth asteroid orbits similar to that of ...
# 19  Near-Earth asteroid orbits similar to that of ...
#
#            orbital_data.orbit_class.orbit_class_range
# 0                  1.017 AU < q (perihelion) < 1.3 AU
# 1                  1.017 AU < q (perihelion) < 1.3 AU
# 2                  1.017 AU < q (perihelion) < 1.3 AU
# 3                  1.017 AU < q (perihelion) < 1.3 AU
# 4                  1.017 AU < q (perihelion) < 1.3 AU
# ..                                                ...
# 15  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 16                 1.017 AU < q (perihelion) < 1.3 AU
# 17                 1.017 AU < q (perihelion) < 1.3 AU
# 18                 1.017 AU < q (perihelion) < 1.3 AU
# 19                 1.017 AU < q (perihelion) < 1.3 AU
#
# [200 rows x 44 columns]

# %% [markdown]
# Comprobemos la cantidad de objetos en el dataframe final, 10 páginas con 20 objetos cada una:

# %%
df_1 = df.reset_index(drop=True)
df_1
# Out:
#           id neo_reference_id                    name name_limited  \
# 0    2000433          2000433      433 Eros (A898 PA)         Eros
# 1    2000719          2000719    719 Albert (A911 TB)       Albert
# 2    2000887          2000887    887 Alinda (A918 AA)       Alinda
# 3    2001036          2001036  1036 Ganymed (A924 UB)      Ganymed
# 4    2001221          2001221    1221 Amor (1932 EA1)         Amor
# ..       ...              ...                     ...          ...
# 195  2017511          2017511         17511 (1992 QN)          NaN
# 196  2018106          2018106  18106 Blume (2000 NX3)        Blume
# 197  2018109          2018109       18109 (2000 NG11)          NaN
# 198  2018172          2018172        18172 (2000 QL7)          NaN
# 199  2018736          2018736         18736 (1998 NU)          NaN
#
#     designation                                   nasa_jpl_url  \
# 0           433  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433
# 1           719  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000719
# 2           887  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000887
# 3          1036  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001036
# 4          1221  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2001221
# ..          ...                                            ...
# 195       17511  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2017511
# 196       18106  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018106
# 197       18109  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018109
# 198       18172  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018172
# 199       18736  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2018736
#
#      absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0                   10.42                              False
# 1                   15.51                              False
# 2                   13.84                              False
# 3                    9.25                              False
# 4                   17.39                              False
# ..                    ...                                ...
# 195                 17.30                              False
# 196                 17.70                              False
# 197                 17.08                              False
# 198                 15.61                              False
# 199                 15.94                              False
#
#                                    close_approach_data  is_sentry_object  ...  \
# 0    [{'close_approach_date': '1900-12-27', 'close_...             False  ...
# 1    [{'close_approach_date': '1909-08-21', 'close_...             False  ...
# 2    [{'close_approach_date': '1910-01-04', 'close_...             False  ...
# 3    [{'close_approach_date': '1910-02-25', 'close_...             False  ...
# 4    [{'close_approach_date': '1900-03-08', 'close_...             False  ...
# ..                                                 ...               ...  ...
# 195  [{'close_approach_date': '1900-12-11', 'close_...             False  ...
# 196  [{'close_approach_date': '1904-08-28', 'close_...             False  ...
# 197  [{'close_approach_date': '1902-10-30', 'close_...             False  ...
# 198  [{'close_approach_date': '1913-11-01', 'close_...             False  ...
# 199  [{'close_approach_date': '1918-04-01', 'close_...             False  ...
#
#     orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                  1.133004746239758                 178.8689344298016
# 1                  1.195376966739327                 156.2074111005377
# 2                  1.062542630695554                 350.5075827027987
# 3                  1.244392487592923                 132.3785381720509
# 4                  1.083392203652344                 26.67758290479227
# ..                               ...                               ...
# 195                .7628812639160113                 202.3575672368542
# 196                1.193699063724138                 234.9170096326625
# 197                1.189336449752271                 319.2321665645002
# 198                1.185283315346584                 100.7630208867756
# 199                1.198402888557957                 222.8832249073757
#
#      orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0                 1.783329728038786          2459159.335547045187
# 1                 4.080683758289534          2459956.001930185700
# 2                  3.88479471264434          2459258.738807182354
# 3                 4.085994582878027          2458979.250423075115
# 4                   2.7549388383389          2458896.584345836670
# ..                              ...                           ...
# 195               1.617050971155794          2459164.094158202908
# 196               3.696433765221722          2458767.595284876645
# 197               2.572445554033802          2459350.582381827407
# 198               3.663375081197811          2458829.950952856585
# 199               3.503564851581627          2459871.090996946585
#
#      orbital_data.mean_anomaly  orbital_data.mean_motion  \
# 0            23.04174776493414         .5597486693246532
# 1            231.2977977256108         .2300299522321089
# 2             34.8994574215934         .2533330084314079
# 3            50.11796125710877          .226522291946004
# 4            112.6648636168215         .3707109590224443
# ..                         ...                       ...
# 195          176.4611969338573         .7592803845607337
# 196          111.5990248305691         .2577911973048602
# 197          17.54437829266421         .3820838055388477
# 198          96.75254254087584         .2611059002492302
# 199          230.2375325755811         .2734195723460461
#
#      orbital_data.equinox  orbital_data.orbit_class.orbit_class_type  \
# 0                   J2000                                        AMO
# 1                   J2000                                        AMO
# 2                   J2000                                        AMO
# 3                   J2000                                        AMO
# 4                   J2000                                        AMO
# ..                    ...                                        ...
# 195                 J2000                                        APO
# 196                 J2000                                        AMO
# 197                 J2000                                        AMO
# 198                 J2000                                        AMO
# 199                 J2000                                        AMO
#
#       orbital_data.orbit_class.orbit_class_description  \
# 0    Near-Earth asteroid orbits similar to that of ...
# 1    Near-Earth asteroid orbits similar to that of ...
# 2    Near-Earth asteroid orbits similar to that of ...
# 3    Near-Earth asteroid orbits similar to that of ...
# 4    Near-Earth asteroid orbits similar to that of ...
# ..                                                 ...
# 195  Near-Earth asteroid orbits which cross the Ear...
# 196  Near-Earth asteroid orbits similar to that of ...
# 197  Near-Earth asteroid orbits similar to that of ...
# 198  Near-Earth asteroid orbits similar to that of ...
# 199  Near-Earth asteroid orbits similar to that of ...
#
#             orbital_data.orbit_class.orbit_class_range
# 0                   1.017 AU < q (perihelion) < 1.3 AU
# 1                   1.017 AU < q (perihelion) < 1.3 AU
# 2                   1.017 AU < q (perihelion) < 1.3 AU
# 3                   1.017 AU < q (perihelion) < 1.3 AU
# 4                   1.017 AU < q (perihelion) < 1.3 AU
# ..                                                 ...
# 195  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 196                 1.017 AU < q (perihelion) < 1.3 AU
# 197                 1.017 AU < q (perihelion) < 1.3 AU
# 198                 1.017 AU < q (perihelion) < 1.3 AU
# 199                 1.017 AU < q (perihelion) < 1.3 AU
#
# [200 rows x 44 columns]

# %% [markdown]
# Guarda tu dataframe en el archivo `objetos_tierra_nasa.csv`:

# %%
df_1.to_csv("objetos_tierra_nasa.csv")

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Automatizar la petición de datos a la API de la NASA por fechas.
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# ### a) Automatizando peticiones
#
# En el primer Reto realizaste una petición a la API de la NASA para pedir 5 datos de la hoja #100. Ahora, vamos a automatizar el proceso de realizar peticiones a la API para obtener una cantidad bastante mayor de datos.
#
# Vamos a obtener ahora los datos por fechas, así que tendrás que ir a la página de la [api de la NASA](https://api.nasa.gov/), para revisar cómo es posible realizar peticiones por fecha. Queremos obtener los **dos primeros meses (Enero y Febrero) del año 1995**. Observa que la API sólo permite peticiones por fecha en rangos de 7 días.
#
# Tu reto tiene los siguientes pasos:
#
# 1. Revisa la documentación de la API de la NASA para entender cómo realizar peticiones por fecha.
# 2. Realiza una primera petición de prueba para entender el formato de los datos que obtienes de regreso (cómo extraemos los datos que necesitamos y qué estructura tienen).
# 2. Escribe el código necesario para automatizar las peticiones a la API y obtener los meses de Enero y Febrero del año 1995.
# 3. Almacena los datos de cada petición y luego usa esos datos para crear `DataFrames`.
# 4. Concatena verticalmente tus `DataFrames` para obtener un `DataFrame` final que contenga todos los datos de tus peticiones. Cada fila tiene que corresponder a un objeto espacial.
# 5. Guarda tu `DataFrame` con el nombre de `near_earth_objects-january_february_1995-raw.csv`.
#
# > **Nota**: En este momento no te preocupes por explorar o limpiar tu dataset. Eso lo haremos en la siguiente sesión. Lo que sí tienes que asegurarte es de normalizar tus datos antes de convertirlos en `DataFrame`.
#
# ¡Mucha suerte!
